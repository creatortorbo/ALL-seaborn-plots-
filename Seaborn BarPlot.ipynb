# %% [markdown]
# # Seaborn BarPlot

# %%
import pandas as pd
import seaborn as sns 
from matplotlib import pyplot as plt

# %%
d = pd.read_csv("C:\\Users\\ASUS\\OneDrive\\Desktop\\csv files\\penguins.csv")
d
# Out:
#     species     island  bill_length_mm  bill_depth_mm  flipper_length_mm  \
# 0    Adelie  Torgersen            39.1           18.7              181.0
# 1    Adelie  Torgersen            39.5           17.4              186.0
# 2    Adelie  Torgersen            40.3           18.0              195.0
# 3    Adelie  Torgersen             NaN            NaN                NaN
# 4    Adelie  Torgersen            36.7           19.3              193.0
# ..      ...        ...             ...            ...                ...
# 339  Gentoo     Biscoe             NaN            NaN                NaN
# 340  Gentoo     Biscoe            46.8           14.3              215.0
# 341  Gentoo     Biscoe            50.4           15.7              222.0
# 342  Gentoo     Biscoe            45.2           14.8              212.0
# 343  Gentoo     Biscoe            49.9           16.1              213.0
#
#      body_mass_g     sex
# 0         3750.0    MALE
# 1         3800.0  FEMALE
# ...

# %%
sns.barplot(x =d.island,y=d.bill_length_mm)
plt.title("python",fontsize= 20) # here we use font size for size
plt.show()

# %%
sns.barplot(x ="island",y="bill_length_mm",data=d)
plt.title("python",fontsize= 20) # here we use font size for size
plt.show()

# %% [markdown]
# # hue parameter --->
# it drow the graph with resepts to another

# %%
sns.barplot(x ="island",y="bill_length_mm",data=d,hue = "sex")
plt.title("python",fontsize= 20) # here we drown the with respects to sex as shown given below :
plt.show()

# %%
d
# Out:
#     species     island  bill_length_mm  bill_depth_mm  flipper_length_mm  \
# 0    Adelie  Torgersen            39.1           18.7              181.0
# 1    Adelie  Torgersen            39.5           17.4              186.0
# 2    Adelie  Torgersen            40.3           18.0              195.0
# 3    Adelie  Torgersen             NaN            NaN                NaN
# 4    Adelie  Torgersen            36.7           19.3              193.0
# ..      ...        ...             ...            ...                ...
# 339  Gentoo     Biscoe             NaN            NaN                NaN
# 340  Gentoo     Biscoe            46.8           14.3              215.0
# 341  Gentoo     Biscoe            50.4           15.7              222.0
# 342  Gentoo     Biscoe            45.2           14.8              212.0
# 343  Gentoo     Biscoe            49.9           16.1              213.0
#
#      body_mass_g     sex
# 0         3750.0    MALE
# 1         3800.0  FEMALE
# ...

# %% [markdown]
# # order parameter ---->
# it can change the order of the given data

# %%
order_1=["Biscoe","Dream","Torgersen"]
sns.barplot(x ="island",y="bill_length_mm",data=d,hue = "sex",order = order_1)
plt.title("python",fontsize= 20) 
plt.show()

# %%
order_1=["Dream","Biscoe","Torgersen"]# here we are changeing the order of the given data 
sns.barplot(x ="island",y="bill_length_mm",data=d,hue = "sex",order = order_1)
plt.title("python",fontsize= 20) 
plt.show()

# %% [markdown]
# # hue _order --->
# In the legend we change the order and with the helps of the hue parameter

# %%
order_1=["Dream","Biscoe","Torgersen"]# here we are changeing the order of the given data 
sns.barplot(x ="island",y="bill_length_mm",data=d,hue = "sex",
            order = order_1,hue_order = ["FEMALE","Male"])
plt.title("python",fontsize= 20) 
plt.show()

# %% [markdown]
# # ci parameter --->
# it is for the incresing and decresing line jn the graph

# %%
order_1=["Dream","Biscoe","Torgersen"]# here we are changeing the order of the given data 
sns.barplot(x ="island",y="bill_length_mm",data=d,hue = "sex",
            order = order_1,ci=10)
plt.title("python",fontsize= 20) 
plt.show()
# Out:
# C:\Users\ASUS\AppData\Local\Temp\ipykernel_23120\2775034121.py:2: FutureWarning:
#
# The `ci` parameter is deprecated. Use `errorbar=('ci', 10)` for the same effect.
#
#   sns.barplot(x ="island",y="bill_length_mm",data=d,hue = "sex",

# %%
order_1=["Dream","Biscoe","Torgersen"]# here we are changeing the order of the given data 
sns.barplot(x ="island",y="bill_length_mm",data=d,hue = "sex",
            order = order_1,ci=100,n_boot = 2)
plt.title("python",fontsize= 20) 
plt.show()
# Out:
# C:\Users\ASUS\AppData\Local\Temp\ipykernel_14172\185940038.py:2: FutureWarning:
#
# The `ci` parameter is deprecated. Use `errorbar=('ci', 100)` for the same effect.
#
#   sns.barplot(x ="island",y="bill_length_mm",data=d,hue = "sex",

# %% [markdown]
# # boot patameter ---> it is to rediuce the size of the line on the graph

# %%
order_1=["Dream","Biscoe","Torgersen"]# here we are changeing the order of the given data 
sns.barplot(x ="island",y="bill_length_mm",data=d,hue = "sex",
            order = order_1,ci=100,n_boot = 5)
plt.title("python",fontsize= 20) 
plt.show()
# Out:
# C:\Users\ASUS\AppData\Local\Temp\ipykernel_14172\3763506458.py:2: FutureWarning:
#
# The `ci` parameter is deprecated. Use `errorbar=('ci', 100)` for the same effect.
#
#   sns.barplot(x ="island",y="bill_length_mm",data=d,hue = "sex",

# %%
order_1=["Dream","Biscoe","Torgersen"]# here we are changeing the order of the given data 
sns.barplot(x ="island",y="bill_length_mm",data=d,hue = "sex",
            order = order_1,ci=100,n_boot =2)
plt.title("python",fontsize= 20) 
plt.show()
# Out:
# C:\Users\ASUS\AppData\Local\Temp\ipykernel_14172\1573623523.py:2: FutureWarning:
#
# The `ci` parameter is deprecated. Use `errorbar=('ci', 100)` for the same effect.
#
#   sns.barplot(x ="island",y="bill_length_mm",data=d,hue = "sex",

# %% [markdown]
# # orient parameter --->
# it is used to convert the graph into (horigintal) axis and only we can take x and y in numbers

# %%
sns.barplot(x ="bill_length_mm",y="bill_depth_mm",data=d,orient = "v")
plt.title("python",fontsize= 20)  # it for the verticle grpah 
plt.show()

# %%
sns.barplot(x ="bill_length_mm",y="bill_depth_mm",data=d,orient = "h")
plt.title("python",fontsize= 20) # it for the horigintal graph 
plt.show()

# %%
order_1=["Dream","Biscoe","Torgersen"]
sns.barplot(x ="island",y="bill_length_mm",data=d,hue = "sex",
            order = order_1,color = "g")
plt.title("python",fontsize= 20) 
plt.show()

# %% [markdown]
# # palette parameter ---->
# it is used for colors code

# %%
order_1=["Dream","Biscoe","Torgersen"]
sns.barplot(x ="island",y="bill_length_mm",data=d,hue = "sex",
            order = order_1,palette="icefire")
plt.title("python",fontsize= 20) 
plt.show()

# %% [markdown]
# # saturation parameter ---->
# it is used to increase and decrease the color of the graph bar (britness)

# %%
order_1=["Dream","Biscoe","Torgersen"]
sns.barplot(x ="island",y="bill_length_mm",data=d,hue = "sex",
            order = order_1,palette="icefire",saturation = 0.3)
plt.title("python",fontsize= 20) 
plt.show()

# %%
order_1=["Dream","Biscoe","Torgersen"]
sns.barplot(x ="island",y="bill_length_mm",data=d,hue = "sex",
            order = order_1,palette="icefire",saturation = 10) 
plt.title("python",fontsize= 20) 
plt.show()

# %% [markdown]
# # errcolor parameter --->
# it used to change the colors of the line which on the bar

# %%
order_1=["Dream","Biscoe","Torgersen"]
sns.barplot(x ="island",y="bill_length_mm",data=d,hue = "sex",
            order = order_1,palette="icefire",saturation = 10,errcolor = "g") 
plt.title("python",fontsize= 20) 
plt.show()

# %%
order_1=["Dream","Biscoe","Torgersen"]
sns.barplot(x ="island",y="bill_length_mm",data=d,hue = "sex",
            order = order_1,palette="icefire",saturation = 10,errcolor = "y") 
plt.title("python",fontsize= 20) 
plt.show()

# %%
order_1=["Dream","Biscoe","Torgersen"]
sns.barplot(x ="island",y="bill_length_mm",data=d,hue = "sex",
            order = order_1,palette="icefire",saturation = 10,errcolor = "b") 
plt.title("python",fontsize= 20) 
plt.show()

# %% [markdown]
# # errwidth parameter --->
# it is used to increase the width or decrese the errwidth

# %%
order_1=["Dream","Biscoe","Torgersen"]
sns.barplot(x ="island",y="bill_length_mm",data=d,hue = "sex",
            order = order_1,palette="icefire",saturation = 10,errcolor = "b",errwidth = 12 ) 
plt.title("python",fontsize= 20) 
plt.show()

# %%
order_1=["Dream","Biscoe","Torgersen"]
sns.barplot(x ="island",y="bill_length_mm",data=d,hue = "sex",
            order = order_1,palette="icefire",saturation = 10,errcolor = "r",errwidth = 5 ) 
plt.title("python",fontsize= 20) 
plt.show()

# %% [markdown]
# # capsize parameter --->
# it indetes the end line of the line on the bar which is increase the endlength

# %%
order_1=["Dream","Biscoe","Torgersen"]
sns.barplot(x ="island",y="bill_length_mm",data=d,hue = "sex",
            order = order_1,palette="icefire",saturation = 10,errcolor = "b",capsize = 1 ) 
plt.title("python",fontsize= 20) 
plt.show()

# %%
order_1=["Dream","Biscoe","Torgersen"]
sns.barplot(x ="island",y="bill_length_mm",data=d,hue = "sex",
            order = order_1,palette="icefire",saturation = 10,errcolor = "r",errwidth = 5,capsize = 1 ) 
plt.title("python",fontsize= 20) 
plt.show()

# %% [markdown]
# # dodge parameter---->
# it is used for one bar laying on another bar

# %%
order_1=["Dream","Biscoe","Torgersen"]
sns.barplot(x ="island",y="bill_length_mm",data=d,hue = "sex",
            order = order_1,palette="icefire",saturation = 10,errcolor = "r", dodge = False) 
plt.title("python",fontsize= 20, )    # here we are laying on one another 
plt.show()

# %% [markdown]
# # alpah parameter --->
# it is used for the light (0-1)

# %%
order_1=["Dream","Biscoe","Torgersen"]
sns.barplot(x ="island",y="bill_length_mm",data=d,hue = "sex",
            order = order_1,palette="icefire",saturation = 100,errcolor = "r", dodge = False,alpha = 0.7) # decrease the light 
plt.title("python",fontsize= 20, )    
plt.show()

# %% [markdown]
# # In seaborn we use gried parameter

# %%
sns.set(style= "darkgrid")
order_1=["Dream","Biscoe","Torgersen"]
sns.barplot(x ="island",y="bill_length_mm",data=d,hue = "sex",
            order = order_1,palette="icefire",saturation = 100,errcolor = "r", dodge = False,alpha = 0.7) # decrease the light 
plt.title("python",fontsize= 20, )    
plt.show()
